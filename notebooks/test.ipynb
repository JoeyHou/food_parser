# %%
from foodparser import *
# Out:
# [nltk_data] Downloading package words to /Users/joey-hou/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/joey-
# [nltk_data]     hou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/joey-
# [nltk_data]     hou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/joey-hou/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
fp = FoodParser()

# %%
fp.parse_single_entry(' fosdf coffee and tea')
# Out:
# ['coffee', 'tea']

# %%
fp.version
# Out:
# '0.1.4'

# %%
import sys
sys.path.insert(1, '../foodparser/')

from foodparser import *
# Out:
# [nltk_data] Downloading package words to /Users/joey-hou/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/joey-
# [nltk_data]     hou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/joey-
# [nltk_data]     hou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/joey-hou/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
fp = FoodParser()
fp.initialization()

# %%
pd.DataFrame(fp.my_stop_words).to_csv('stop_words.csv', index = False)

# %%
pd.DataFrame(list(fp.final_measurement)).to_csv('measurement.csv', index = False)

# %%
fp.gram_mask
# Out:
# {'coffee black': 'black coffee'}

# %%
fp.correction_dic
# Out:
# {'kevita': 'kevita',
#  'kambucha': 'kombucha ',
#  'emergen': 'emergen-c',
#  'ginerale': 'ginger ale',
#  'coffeeee': 'coffee',
#  'gingerale': 'ginger ale',
#  'bcaa': 'bcaa',
#  'coffe': 'coffee',
#  'prework': 'preworkout ',
#  'chocloate': 'chocolate',
#  'organifi': 'organic',
#  'coffeee': 'coffee',
#  'promeganate': 'pomegranate',
#  'virgils': 'virgils',
#  'recoverite': 'recoverite',
#  'protien': 'protein',
#  'wsprite': 'sprite',
#  'trulys': 'truly',
#  'seltzers': 'seltzer',
#  'tumeric': 'turmeric ',
#  'michaelob': 'michaelob beer',
#  'bday': 'birthday ',
#  'smoothy': 'smoothie',
#  'tbls': 'tbs',
#  'accelerade': 'accelerade',
#  'rebbl': 'rebbl',
#  'dalgona': 'dalgona',
#  'cocnut': 'coconut',
#  'xshot': 'shot',
#  'emergenc': 'emergen c',
#  'reishi': 'relish',
#  'maragarita': 'margarita',
#  'juneshine': 'juneshine',
#  'jarritos': 'jarritos ',
#  'orgain': 'orgrain',
#  'leminade': 'lemonade',
#  'ligjt': 'light',
#  'owyn': 'own',
# ...

# %%
# fm = []
# for m in fp.final_measurement:
#     if m not in fp.food_type_dict.keys():
#         fm.append(m)
# fm
